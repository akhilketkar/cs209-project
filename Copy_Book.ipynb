# %%
import statsmodels.api as sm
import statsmodels.tools.tools as smtools
from patsy import dmatrices

import numpy as np
import pandas as pd
import collections
import itertools
import sklearn.cross_validation

import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.corpus import movie_reviews
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.corpus import stopwords

import re
import zipfile
import json
from math import *

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ###     In this notebook, we are performing regression and sentiment analysis. We have previously scraped data from over a thousand movies and stored this in .csv files, using the Rotten Tomatoes  api. Additional data including movie budget and revenue was scraped from "thenumbers.com." The data below is pulled from the .csv files and placed into a DataFrame for analysis.

# %%
# load and clean data
dataMain = pd.read_csv("movieRTAndBudgetData.csv")
dataMain = dataMain.dropna()
dataMain.head()
dataMain = dataMain[(dataMain["Worldwide"] > 0 ) & (dataMain["CriticsScore"] > 0)]

# Change to millions
dataMain["Worldwide"] = dataMain["Worldwide"] / 1e6
dataMain["Domestic"] = dataMain["Domestic"] / 1e6
dataMain["Budget"] = dataMain["Budget"] / 1e6


# add more columns
dataMain["PR"] = dataMain["Worldwide"] / dataMain["Budget"]
dataMain["logPR"] = np.log(dataMain["PR"])
dataMain["logWorldwide"] = np.log(dataMain["Worldwide"])
dataMain["logBudget"] = np.log(dataMain["Budget"])
dataMain.head()
# Out:
#    AudScore                                               Cast  CriticsScore  \
# 0        90  [{"name": "Christian Bale", "characters": ["Br...            88
# 1        52  [{"name": "Johnny Depp", "characters": ["Tonto...            31
# 2        60  [{"name": "Antonio Sabato Jr.", "id": "2706744...            51
# 3        87  [{"name": "Ron Perlman", "characters": ["Stabb...            89
# 4        83  [{"name": "Orlando Bloom", "characters": ["Leg...            64
#
#                                 Name  \
# 0              The Dark Knight Rises
# 1                    The Lone Ranger
# 2                        John Carter
# 3                            Tangled
# 4  The Hobbit: An Unexpected Journey
#
#                                               RTData       RTID  Rank  \
# 0  {"ratings": {"critics_score": 88, "audience_sc...  771041731     3
# 1  {"ratings": {"critics_score": 31, "audience_sc...  771017189     4
# 2  {"ratings": {"critics_score": 51, "audience_sc...  770801433     5
# 3  {"ratings": {"critics_score": 89, "audience_sc...  770678818     6
# 4  {"ratings": {"critics_score": 64, "audience_sc...  770675766     8
#
#                                              Ratings  \
# 0  {"critics_score": 88, "audience_score": 90, "c...
# 1  {"critics_score": 31, "audience_score": 52, "c...
# 2  {"critics_score": 51, "audience_score": 60, "c...
# 3  {"critics_score": 89, "audience_score": 87, "c...
# 4  {"critics_score": 64, "audience_score": 83, "c...
#
#                                              RevLink ReleaseDate  Budget  \
# 0  http://api.rottentomatoes.com/api/public/v1.0/...  2012-07-20     275
# 1  http://api.rottentomatoes.com/api/public/v1.0/...  2013-07-02     275
# 2  http://api.rottentomatoes.com/api/public/v1.0/...  2012-03-09     275
# 3  http://api.rottentomatoes.com/api/public/v1.0/...  2010-11-24     260
# 4  http://api.rottentomatoes.com/api/public/v1.0/...  2012-12-14     250
#
#      Domestic    Worldwide  Year  Month        PR     logPR  logWorldwide  \
# 0  448.139099  1079.343943  2012      7  3.924887  1.367338      6.984109
# 1   89.289910   259.989910  2013      7  0.945418 -0.056128      5.560643
# 2   73.058679   282.778100  2012      3  1.028284  0.027891      5.644662
# 3  200.821936   586.581936  2010     11  2.256084  0.813631      6.374312
# 4  303.003568  1014.703568  2012     12  4.058814  1.400891      6.922352
#
#    logBudget
# 0   5.616771
# 1   5.616771
# 2   5.616771
# 3   5.560682
# 4   5.521461

# %% [markdown]
# ### We are now performing Exploratory Data Analysis in order to interpret possible relationships between the performance of movies and their associated attributes, including: critics and audience scores, and budget.

# %%
# Plot relationship between Audience Score and Critics Score
dataMain.plot("AudScore","CriticsScore",kind="Scatter", alpha=0.5,
              title="Critics v/s Audience, R=" + str(round(np.corrcoef(dataMain.AudScore, 
                                                                     dataMain.CriticsScore)[0][1],2)) ,figsize=(12,7))
m, b = np.polyfit(dataMain.AudScore, dataMain.CriticsScore, 1)
x = np.linspace(dataMain.AudScore.min(), dataMain.AudScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# Plot budget and revenue
dataMain.plot("Budget","Worldwide",kind="Scatter",alpha=0.5,
              title="Revenue v/s Budget, R=" + str(round(np.corrcoef(dataMain.Budget, 
                                                                     dataMain.Worldwide)[0][1],2)) ,figsize=(12,7))
m, b = np.polyfit(dataMain.Budget, dataMain.Worldwide, 1)
x = np.linspace(dataMain.Budget.min(), dataMain.Budget.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# Plot Revenue and Critics Score
dataMain.plot("CriticsScore","Worldwide",kind="Scatter",alpha=0.5,
              title="Revenue v/s Critics Score, R=" + str(round(np.corrcoef(dataMain.CriticsScore, 
                                                                     dataMain.Worldwide)[0][1],2)) ,figsize=(12,7))
m, b = np.polyfit(dataMain.CriticsScore, dataMain.Worldwide, 1)
x = np.linspace(dataMain.CriticsScore.min(), dataMain.CriticsScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# Plot Revenue and Critics Score
dataMain.plot("AudScore","Worldwide",kind="Scatter",alpha=0.5,
              title="Revenue v/s Audience Score, R=" + str(round(np.corrcoef(dataMain.AudScore, 
                                                                     dataMain.Worldwide)[0][1],2)) ,figsize=(12,7))
m, b = np.polyfit(dataMain.AudScore, dataMain.Worldwide, 1)
x = np.linspace(dataMain.AudScore.min(), dataMain.AudScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# Histogram of Revenue
dataMain.hist("logWorldwide",figsize=(9,9), bins=50)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x113af9310>]], dtype=object)

# %% [markdown]
# 1> Critics scores and Audience Scores are very correlated.
#
# 2> Revenue is clearly related to the budget but there is a lot of data clustered close to 0
#
# 3> The critics score on it's own or the audience score on it's own are not good predictors of the movie will do at the box office. There are too many data points clustered along the x axis in the above graphs.
#
# 4> The log of Worldwide revenue seems relatively normally distributed but has a long left tail. This might mean that splitting the data into subgroups might give better results. i.e different relationships might hold across in different regions

# %% [markdown]
# ### We then furthered our EDA to determine if stronger correlations could be found between movies and their attributes, if we divided the movie's budget in to quartiles.

# %%
# split data by groups and see if there's a relationship
dataMain["BudgetQ"] = pd.qcut(dataMain["Budget"],np.linspace(0.,1.,4))

for i in pd.unique(dataMain["BudgetQ"]):
    dataQuartile = dataMain[dataMain["BudgetQ"] == i]
    y, X = dmatrices("logWorldwide ~ logBudget + CriticsScore", data=dataQuartile, return_type="dataframe")
    model = sm.OLS(y,X)
    #model = sm.GLM(y,X,family=sm.families.Poisson())
    res = model.fit()
    dataQuartile["FitValues"] = res.fittedvalues    
    print "Budget between",i
    print res.summary()
    ax = dataQuartile.plot("CriticsScore","logWorldwide",kind="Scatter",alpha=0.5,title="Log Revenue v/s Critics Score. Budget in:" + str(i),figsize=(9,9))
    dataQuartile.plot("CriticsScore","FitValues",alpha=0.5,color="green",ax=ax,kind="Scatter",)
    dataQuartile.hist("logWorldwide")
# Out:
# Budget between (40, 275]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.494
# Method:                 Least Squares   F-statistic:                     134.0
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           3.37e-41
# Time:                        23:04:38   Log-Likelihood:                -288.82
# No. Observations:                 274   AIC:                             583.6
# Df Residuals:                     271   BIC:                             594.5
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       -0.3543      0.379     -0.935      0.351        -1.100     0.392
# logBudget        1.1526      0.086     13.393      0.000         0.983     1.322
# CriticsScore     0.0093      0.002      5.637      0.000         0.006     0.013
# ==============================================================================
# Omnibus:                       29.645   Durbin-Watson:                   1.451
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.728
# Skew:                          -0.699   Prob(JB):                     5.27e-10
# Kurtosis:                       4.338   Cond. No.                         536.
# ==============================================================================
# Budget between
#  (15, 40]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     19.75
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           1.03e-08
# Time:                        23:04:38   Log-Likelihood:                -467.94
# No. Observations:                 264   AIC:                             941.9
# Df Residuals:                     261   BIC:                             952.6
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       -2.5431      1.041     -2.443      0.015        -4.593    -0.493
# logBudget        1.7977      0.315      5.704      0.000         1.177     2.418
# CriticsScore     0.0080      0.003      2.411      0.017         0.001     0.015
# ==============================================================================
# Omnibus:                      196.830   Durbin-Watson:                   1.291
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2545.832
# Skew:                          -2.907   Prob(JB):                         0.00
# Kurtosis:                      17.058   Cond. No.                         673.
# ==============================================================================
# Budget between
#  [0.009, 15]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     42.82
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           5.69e-17
# Time:                        23:04:39   Log-Likelihood:                -642.14
# No. Observations:                 286   AIC:                             1290.
# Df Residuals:                     283   BIC:                             1301.
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       -0.1797      0.410     -0.438      0.662        -0.987     0.628
# logBudget        0.9878      0.107      9.239      0.000         0.777     1.198
# CriticsScore     0.0056      0.005      1.050      0.295        -0.005     0.016
# ==============================================================================
# Omnibus:                       39.488   Durbin-Watson:                   1.444
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.101
# Skew:                          -0.925   Prob(JB):                     2.95e-12
# Kurtosis:                       4.015   Cond. No.                         204.
# ==============================================================================

# %% [markdown]
# The model works best for big budget movies. It works reasonably well for low budgest movies but is not great for medium budget movies.

# %% [markdown]
# ## Looking at profitability instead of raw revenue. It is much harder to forecast

# %%
for i in pd.unique(dataMain["BudgetQ"]):
    dataPRQ = dataMain[dataMain["BudgetQ"] == i]
    y, X = dmatrices("PR ~ Budget + CriticsScore", data=dataPRQ, return_type="dataframe")
    model = sm.OLS(y,X)
    res = model.fit()
    dataPRQ["FitValues"] = res.fittedvalues
    print "Profitability between",i
    print res.summary()
    ax = dataPRQ.plot("CriticsScore","PR",kind="Scatter",alpha=0.5,title="Revenue/Budget v/s Critics Score. Profitability in:" + str(i),figsize=(9,9))
    dataPRQ.plot("CriticsScore","FitValues",alpha=0.5,color="green",ax=ax,kind="Scatter",)
    dataPRQ.hist("PR")
# Out:
# Profitability between (40, 275]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     18.31
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           3.48e-08
# Time:                        23:04:50   Log-Likelihood:                -557.74
# No. Observations:                 274   AIC:                             1121.
# Df Residuals:                     271   BIC:                             1132.
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        1.5263      0.295      5.177      0.000         0.946     2.107
# Budget           0.0002      0.002      0.113      0.910        -0.004     0.004
# CriticsScore     0.0256      0.004      5.805      0.000         0.017     0.034
# ==============================================================================
# Omnibus:                      106.758   Durbin-Watson:                   1.685
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              367.150
# Skew:                           1.684   Prob(JB):                     1.88e-80
# Kurtosis:                       7.563   Cond. No.                         338.
# ==============================================================================
# Profitability between
#  (15, 40]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     12.19
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           8.66e-06
# Time:                        23:04:50   Log-Likelihood:                -599.25
# No. Observations:                 264   AIC:                             1204.
# Df Residuals:                     261   BIC:                             1215.
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        1.4095      0.597      2.359      0.019         0.233     2.586
# Budget          -0.0005      0.019     -0.027      0.978        -0.039     0.038
# CriticsScore     0.0269      0.005      4.933      0.000         0.016     0.038
# ==============================================================================
# Omnibus:                      118.400   Durbin-Watson:                   1.523
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              478.402
# Skew:                           1.886   Prob(JB):                    1.31e-104
# Kurtosis:                       8.409   Cond. No.                         247.
# ==============================================================================
# Profitability between
#  [0.009, 15]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     5.620
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):            0.00404
# Time:                        23:04:50   Log-Likelihood:                -1075.8
# No. Observations:                 286   AIC:                             2158.
# Df Residuals:                     283   BIC:                             2169.
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       11.0162      1.942      5.673      0.000         7.194    14.838
# Budget          -0.3966      0.133     -2.987      0.003        -0.658    -0.135
# CriticsScore    -0.0463      0.024     -1.903      0.058        -0.094     0.002
# ==============================================================================
# Omnibus:                      288.688   Durbin-Watson:                   1.543
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8865.595
# Skew:                           4.217   Prob(JB):                         0.00
# Kurtosis:                      28.939   Cond. No.                         210.
# ==============================================================================

# %% [markdown]
# ### We included the fitted model for the audience scores as well.

# %%
for i in pd.unique(dataMain["BudgetQ"]):
    dataPRQ = dataMain[dataMain["BudgetQ"] == i]
    y, X = dmatrices("PR ~ Budget + AudScore", data=dataPRQ, return_type="dataframe")
    model = sm.OLS(y, X)
    res = model.fit()
    dataPRQ["FitValues"] = res.fittedvalues
    print "Budget between",i
    print res.summary()
    ax = dataPRQ.plot("AudScore","PR",kind="Scatter",alpha=0.5,title="Revenue/Budget v/s Audience Score. Budget in:" + str(i),figsize=(9,9))
    dataPRQ.plot("AudScore","FitValues",alpha=0.5,color="green",ax=ax,kind="Scatter",)
# Out:
# Budget between (40, 275]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.186
# Method:                 Least Squares   F-statistic:                     32.28
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           2.67e-13
# Time:                        23:04:54   Log-Likelihood:                -545.83
# No. Observations:                 274   AIC:                             1098.
# Df Residuals:                     271   BIC:                             1108.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.2838      0.425     -0.668      0.505        -1.120     0.553
# Budget        -0.0011      0.002     -0.565      0.573        -0.005     0.003
# AudScore       0.0530      0.007      7.834      0.000         0.040     0.066
# ==============================================================================
# Omnibus:                      100.353   Durbin-Watson:                   1.693
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              343.524
# Skew:                           1.571   Prob(JB):                     2.54e-75
# Kurtosis:                       7.497   Cond. No.                         522.
# ==============================================================================
# Budget between
#  (15, 40]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.139
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     21.11
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):           3.17e-09
# Time:                        23:04:55   Log-Likelihood:                -591.24
# No. Observations:                 264   AIC:                             1188.
# Df Residuals:                     261   BIC:                             1199.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.4751      0.709     -0.670      0.504        -1.872     0.922
# Budget         0.0011      0.019      0.060      0.952        -0.036     0.038
# AudScore       0.0552      0.009      6.494      0.000         0.038     0.072
# ==============================================================================
# Omnibus:                      130.322   Durbin-Watson:                   1.595
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              659.091
# Skew:                           2.004   Prob(JB):                    7.59e-144
# Kurtosis:                       9.622   Cond. No.                         326.
# ==============================================================================
# Budget between
#  [0.009, 15]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     3.959
# Date:                Tue, 09 Dec 2014   Prob (F-statistic):             0.0202
# Time:                        23:04:55   Log-Likelihood:                -1077.4
# No. Observations:                 286   AIC:                             2161.
# Df Residuals:                     283   BIC:                             2172.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      9.2649      2.393      3.872      0.000         4.555    13.975
# Budget        -0.3684      0.133     -2.778      0.006        -0.629    -0.107
# AudScore      -0.0212      0.034     -0.622      0.535        -0.088     0.046
# ==============================================================================
# Omnibus:                      293.939   Durbin-Watson:                   1.514
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9619.849
# Skew:                           4.314   Prob(JB):                         0.00
# Kurtosis:                      30.071   Cond. No.                         246.
# ==============================================================================

# %% [markdown]
# ### Review of the mean of each attribute by budgetary quintile for the movies.

# %%
# Look at means by quintiles
dataGroupBQ = dataMain.groupby("BudgetQ")
dataGroupBQ.mean()
# Out:
#               AudScore  CriticsScore          RTID         Rank      Budget  \
# BudgetQ
# (15, 40]     56.500000     47.625000  7.711044e+08  1719.454545   27.427652
# (40, 275]    61.821168     51.675182  7.707467e+08   433.335766  105.207664
# [0.009, 15]  60.937063     61.618881  7.711176e+08  3341.174825    6.675248
#
#                Domestic   Worldwide         Year     Month        PR  \
# BudgetQ
# (15, 40]      39.962825   73.635195  2011.696970  6.765152  2.675915
# (40, 275]    115.381658  312.891333  2011.872263  6.613139  2.872770
# [0.009, 15]   15.301997   28.775913  2011.482517  6.737762  5.513164
#
#                 logPR  logWorldwide  logBudget
# BudgetQ
# (15, 40]     0.448607      3.721716   3.273109
# (40, 275]    0.816585      5.342001   4.525416
# [0.009, 15]  0.150815      1.575979   1.425165

# %% [markdown]
# ### We then looked for evidence of the "Tom Cruise" effect, or effect of a high-priced, big-named actor has on the revenue of a film. Is it really worth the studio's money to pay for this talent? Or can much cheaper alternative be hired for a samiliary value? We see below that most actors/actress are overpaid.

# %%
actors = {}
numInclude = 25

def getActors(row):
    cast = json.loads(row.Cast)
    for person in cast:
        if person["name"] in actors.keys(): actors[person["name"]] += row.Worldwide
        else: actors[person["name"]] = row.Worldwide
    return None

def checkActors(row,actorName):
    cast = json.loads(row.Cast)
    for person in cast:
        if person["name"] == actorName: return True
    
    return False

# get numbers of movies each actor has been in
success = dataMain.apply(getActors,1)

# get sorted list of actors by number of films
actorsList = sorted(actors.keys(),key=lambda x: actors[x],reverse=True)

# create binary variables for the top x actors
dataMainActors = dataMain.copy()
actorsToUse = actorsList[:numInclude]
actorsToUse.append("Tom Cruise")
for a in actorsToUse:
    dataMainActors[a] = dataMainActors.apply(checkActors,1,args=(a,))

# regression using top actors
indepVariables = actorsToUse[:]
indepVariables.append("logBudget")
indepVariables.append("CriticsScore")
# indepVariables.append("AudScore")

for i in pd.unique(dataMain["BudgetQ"]):
    dataPRQ = dataMainActors[dataMainActors["BudgetQ"] == i]
    y,X = dataPRQ["logWorldwide"],dataPRQ[indepVariables]
    model = sm.OLS(y, X)
    res = model.fit()
    print "Budget between",i
    print res.summary()
# Out:
# Budget between (40, 275]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                
# Scarlett Johansson            2.1683      2.813      0.771      0.442        -3.371     7.707
# Jennifer Lawrence             2.0249      1.333      1.519      0.130        -0.600     4.650
# Jonah Hill                    0.1801      2.304      0.078      0.938        -4.355     4.715
# Chris Evans                  -1.7735      2.303     -0.770      0.442        -6.309     2.762
# Tyrese Gibson             -7.772e-14   9.98e-14     -0.779      0.437     -2.74e-13  1.19e-13
# Liam Neeson                  -0.3720      2.304     -0.161      0.872        -4.909     4.165
# Dwayne "The Rock" Johnson     1.0784      2.305      0.468      0.640        -3.461     5.617
# Joseph Gordon-Levitt         -0.7911      1.633     -0.484      0.628        -4.006     2.424
# Emma Stone                    2.0624      2.304      0.895      0.372        -2.475     6.600
# Mark Wahlberg                 2.2639      2.306      0.982      0.327        -2.276     6.804
# Leonardo DiCaprio         -1.438e-14   2.98e-14     -0.482      0.630      -7.3e-14  4.43e-14
# Hugh Jackman                  0.8817      2.306      0.382      0.703        -3.659     5.422
# Jamie Foxx                 1.605e-14   3.54e-14      0.454      0.650     -5.36e-14  8.57e-14
# Steve Carell                  0.5483      1.632      0.336      0.737        -2.665     3.762
# Ralph Fiennes                -2.4629      2.306     -1.068      0.286        -7.003     2.077
# Tom Hardy                  1.858e-16   2.85e-16      0.652      0.515     -3.75e-16  7.47e-16
# Stanley Tucci             -1.333e-16   3.61e-16     -0.370      0.712     -8.43e-16  5.77e-16
# Josh Hutcherson               7.8078      3.252      2.401      0.017         1.406    14.210
# Mark Ruffalo                 -5.8383      2.305     -2.532      0.012       -10.378    -1.299
# Guy Pearce                    0.4083      2.306      0.177      0.860        -4.132     4.949
# Tom Cruise                         0          0        nan        nan             0         0
# logBudget                     0.9709      0.094     10.340      0.000         0.786     1.156
# CriticsScore                  0.0030      0.003      1.094      0.275        -0.002     0.008
# ==============================================================================
# Omnibus:                       42.518   Durbin-Watson:                   1.455
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.736
# Skew:                          -0.939   Prob(JB):                     6.48e-14
# Kurtosis:                       4.251   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is -1.21e-10. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Interestly, the actor with the most significant impact to blockbuster performance is Liam Neeson. Get ready for Taken 12.

# %% [markdown]
# ## We now try to predict the revenues for movies made in 2014 using data from previous years

# %%
# Model 1 -- only includes budget

#spilt the data into test and train, ignore indie movies
dataTrain = dataMainActors[(dataMainActors["Year"] < 2014) & (dataMainActors["Budget"] > 15)]
dataTest = dataMainActors[(dataMainActors["Year"] == 2014) & (dataMainActors["Budget"] > 15) & (dataMainActors["Month"] < 10)]

# train the model
y,X = dataTrain["logWorldwide"],dataTrain[["logBudget"]]
model = sm.OLS(y, X)
res = model.fit()
print res.summary()
# print res.params

# predict the revenues for the test dataset
Xbar = dataTest[["logBudget"]]
dataTest["predLogWorldwide"] = res.predict(Xbar)
dataTest["predWorldwide"] = dataTest["predLogWorldwide"].apply(lambda x: exp(x))

# plot the results
dataTest.plot("predWorldwide","Worldwide",kind="scatter",
              figsize=(9,9),alpha=0.5,title="Actual v/s Predicted Revenue, R= " + str(np.round(res.rsquared, 2)))
m, b = np.polyfit(dataTest.predWorldwide, dataTest.Worldwide, 1)
x = np.linspace(dataTest.predWorldwide.min(), dataTest.predWorldwide.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show

plt.xlim((-1,1000))
plt.ylim((-1,1000))

# show the results
dataTest = dataTest.sort("Worldwide",ascending=False)
dataTest[["Name","Worldwide","predWorldwide","Budget","CriticsScore"]]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     8121.
# Date:                Wed, 10 Dec 2014   Prob (F-statistic):          1.98e-294
# Time:                        11:22:29   Log-Likelihood:                -699.54
# No. Observations:                 461   AIC:                             1401.
# Df Residuals:                     460   BIC:                             1405.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# logBudget      1.1687      0.013     90.119      0.000         1.143     1.194
# ==============================================================================
# Omnibus:                      293.585   Durbin-Watson:                   1.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3784.169
# Skew:                          -2.551   Prob(JB):                         0.00
# Kurtosis:                      16.076   Cond. No.                         1.00
# ==============================================================================
#                                     Name    Worldwide  predWorldwide  Budget  \
# 12       Transformers: Age of Extinction  1081.139076     517.611861     210
# 39               Guardians of the Galaxy   767.805224     404.344124     170
# 34                            Maleficent   751.286891     432.277610     180
# 21            X-Men: Days of Future Past   744.321534     488.922523     200
# 41   Captain America: The Winter Soldier   713.846958     404.344124     170
# 22              The Amazing Spider-Man 2   708.996336     488.922523     200
# 42        Dawn of the Planet of the Apes   703.490841     404.344124     170
# 68            How to Train Your Dragon 2   615.934091     335.749579     145
# 53                              Godzilla   508.172193     376.686629     160
# 81                                 Rio 2   493.738435     295.521952     130
# 91          Teenage Mutant Ninja Turtles   464.177931     282.281677     125
# 209                       The Lego Movie   457.784718     119.714204      60
# 291                                 Lucy   450.573960      74.532522      40
# 36                      Edge of Tomorrow   364.406256     426.669468     178
# 83                                  Noah   356.200044     295.521952     130
# 107               300: Rise of an Empire   330.780051     243.107834     110
# 242                       22 Jump Street   330.634675      96.739904      50
# 364                      The Maze Runner   325.029385      61.639188      34
# 141                            Divergent   286.347895     179.859732      85
# 547                            Neighbors   269.970483      29.312396      18
# 69                 Mr. Peabody & Sherman   269.806430     335.749579     145
# 100                              RoboCop   242.981799     269.130474     120
# 121                             Hercules   242.288614     217.481765     100
# 245                             Non-Stop   212.742160      96.739904      50
# 124                    The Expendables 3   195.322544     217.481765     100
# 295                      The Other Woman   195.111193      74.532522      40
# 195                       Need for Speed   187.268507     133.820234      66
# 228                        The Equalizer   186.915469     108.138853      55
# 379             The Grand Budapest Hotel   158.076019      55.331373      31
# 254                       Into the Storm   156.567524      96.739904      50
# ..                                   ...          ...            ...     ...
# 162                              Pompeii   108.469033     167.557167      80
# 250              Planes: Fire and Rescue    96.657732      96.739904      50
# 497                                Tammy    92.025432      33.153442      20
# 126                        Transcendence    90.022309     217.481765     100
# 399                 Deliver Us from Evil    87.937815      53.251088      30
# 303    A Million Ways to Die in The West    86.587088      74.532522      40
# 203                      I, Frankenstein    71.519465     131.453620      65
# 471                 Think Like a Man Too    70.027933      41.026895      24
# 231                  Muppets Most Wanted    68.493504     108.138853      55
# 480                           Son of God    67.513026      37.059941      22
# 385                          The Nut Job    66.251538      53.251088      30
# 481             The Hundred-Foot Journey    66.082798      37.059941      22
# 186               The Legend of Hercules    61.402445     143.346522      70
# 302                          Jersey Boys    59.447013      74.532522      40
# 447                            The Giver    54.972596      43.031696      25
# 425                       Brick Mansions    50.236829      49.125855      28
# 338                       Dolphin Tale 2    44.658250      65.897435      36
# 423          A Walk Among the Tombstones    42.517685      49.125855      28
# 204         Sin City: A Dame to Kill For    39.499349     131.453620      65
# 449                   Million Dollar Arm    36.947959      43.031696      25
# 515                         Endless Love    34.589731      33.153442      20
# 507            This is Where I Leave You    34.119811      33.153442      20
# 421                       3 Days to Kill    33.622417      49.125855      28
# 398                            Get on Up    32.042803      53.251088      30
# 451                            Draft Day    28.842237      43.031696      25
# 221                        Winter's Tale    22.468620     119.714204      60
# 360                             Sabotage    18.376443      63.763179      35
# 554                            Labor Day    13.371528      29.312396      18
# 187      Legends of Oz: Dorothys Return     8.462347     143.346522      70
# 365                   The House of Magic     0.004091      61.639188      34
#
#      CriticsScore
# 12             18
# 39             90
# 34             49
# 21             92
# 41             89
# 22             53
# 42             91
# 68             92
# 53             73
# 81             48
# 91             22
# 209            96
# 291            66
# 36             90
# 83             77
# 107            42
# 242            84
# 364            63
# 141            41
# 547            73
# 69             79
# 100            48
# 121            58
# 245            60
# 124            33
# 295            24
# 195            22
# 228            61
# 379            92
# 254            21
# ..            ...
# 162            29
# 250            44
# 497            24
# 126            19
# 399            28
# 303            33
# 203             3
# 471            23
# 231            79
# 480            21
# 385            10
# 481            67
# 186             3
# 302            53
# 447            36
# 425            26
# 338            69
# 423            66
# 204            44
# 449            61
# 515            15
# 507            42
# 421            29
# 398            80
# 451            60
# 221            13
# 360            19
# 554            34
# 187            16
# 365            70
#
# [66 rows x 5 columns]

# %%
# Model 2 -- Final Model: Budget and Critics Score

#spilt the data into test and train, ignore indie movies
dataTrain = dataMainActors[(dataMainActors["Year"] < 2014) & (dataMainActors["Budget"] > 15)]
dataTest = dataMainActors[(dataMainActors["Year"] == 2014) & (dataMainActors["Budget"] > 15) & (dataMain["Month"] < 10)]

# train the model
y,X = dataTrain["logWorldwide"],dataTrain[["logBudget","CriticsScore"]]
model = sm.OLS(y, X)
res = model.fit()
print res.summary()
# print res.params

# predict the revenues for the test dataset
Xbar = dataTest[["logBudget","CriticsScore"]]
dataTest["predLogWorldwide"] = res.predict(Xbar)
dataTest["predWorldwide"] = dataTest["predLogWorldwide"].apply(lambda x: exp(x))

# plot the results
dataTest.plot("predWorldwide","Worldwide",kind="scatter",figsize=(9,9),
              alpha=0.5,title="Actual v/s Predicted Revenue, R= " + str(np.round(res.rsquared, 2)))
m, b = np.polyfit(dataTest.predWorldwide, dataTest.Worldwide, 1)
x = np.linspace(dataTest.predWorldwide.min(), dataTest.predWorldwide.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show
plt.xlim((-1,1000))
plt.ylim((-1,1000))

# show the results
dataTest = dataTest.sort("Worldwide",ascending=False)
dataTest[["Name","Worldwide","predWorldwide","Budget","CriticsScore"]]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     4203.
# Date:                Wed, 10 Dec 2014   Prob (F-statistic):          7.68e-296
# Time:                        11:16:21   Log-Likelihood:                -691.53
# No. Observations:                 461   AIC:                             1387.
# Df Residuals:                     459   BIC:                             1395.
# Df Model:                           2
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# 507            This is Where I Leave You    34.119811      34.289419      20
# 421                       3 Days to Kill    33.622417      44.598481      28
# 398                            Get on Up    32.042803      70.666291      30
# 451                            Draft Day    28.842237      49.936277      25
# 221                        Winter's Tale    22.468620      89.561543      60
# 360                             Sabotage    18.376443      52.540681      35
# 554                            Labor Day    13.371528      28.821546      18
# 187      Legends of Oz: Dorothys Return     8.462347     108.112138      70
# 365                   The House of Magic     0.004091      74.936849      34
#
#      CriticsScore
# 12             18
# 39             90
# 34             49
# 21             92
# 41             89
# 22             53
# 42             91
# 68             92
# 53             73
# 81             48
# 91             22
# 209            96
# 291            66
# 36             90
# 83             77
# 107            42
# 242            84
# 364            63
# 141            41
# 547            73
# 69             79
# 100            48
# 121            58
# 245            60
# 124            33
# 295            24
# 195            22
# 228            61
# 379            92
# 254            21
# ..            ...
# 162            29
# 250            44
# 497            24
# 126            19
# 399            28
# 303            33
# 203             3
# 471            23
# 231            79
# 480            21
# 385            10
# 481            67
# 186             3
# 302            53
# 447            36
# 425            26
# 338            69
# 423            66
# 204            44
# 449            61
# 515            15
# 507            42
# 421            29
# 398            80
# 451            60
# 221            13
# 360            19
# 554            34
# 187            16
# 365            70
#
# [66 rows x 5 columns]

# %%
# Model 3 -- Final Model: Budget and Audience Score

#spilt the data into test and train, ignore indie movies
dataTrain = dataMainActors[(dataMainActors["Year"] < 2014) & (dataMainActors["Budget"] > 15)]
dataTest = dataMainActors[(dataMainActors["Year"] == 2014) & (dataMainActors["Budget"] > 15) & (dataMain["Month"] < 10)]

# train the model
y,X = dataTrain["logWorldwide"],dataTrain[["logBudget","AudScore"]]
model = sm.OLS(y, X)
res = model.fit()
print res.summary()
# print res.params

# predict the revenues for the test dataset
Xbar = dataTest[["logBudget","AudScore"]]
dataTest["predLogWorldwide"] = res.predict(Xbar)
dataTest["predWorldwide"] = dataTest["predLogWorldwide"].apply(lambda x: exp(x))

# plot the results
dataTest.plot("predWorldwide","Worldwide",kind="scatter",figsize=(9,9),alpha=0.5, 
              title="Actual v/s Predicted Revenue, R= " + str(np.round(res.rsquared, 2)))

m, b = np.polyfit(dataTest.predWorldwide, dataTest.Worldwide, 1)
x = np.linspace(dataTest.predWorldwide.min(), dataTest.predWorldwide.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()
plt.xlim((-1,1000))
plt.ylim((-1,1000))

# show the results
dataTest = dataTest.sort("Worldwide",ascending=False)
dataTest[["Name","Worldwide","predWorldwide","Budget","AudScore"]]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     4347.
# Date:                Wed, 10 Dec 2014   Prob (F-statistic):          5.15e-299
# Time:                        11:14:18   Log-Likelihood:                -684.19
# No. Observations:                 461   AIC:                             1372.
# Df Residuals:                     459   BIC:                             1381.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# logBudget      0.9406      0.042     22.144      0.000         0.857     1.024
# AudScore       0.0155      0.003      5.622      0.000         0.010     0.021
# ==============================================================================
# Omnibus:                      332.511   Durbin-Watson:                   1.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             
# 365                   The House of Magic     0.004091      65.859383      34
#
#      AudScore
# 12         53
# 39         94
# 34         72
# 21         92
# 41         92
# 22         67
# 42         90
# 68         91
# 53         68
# 81         60
# 91         56
# 209        87
# 291        48
# 36         91
# 83         43
# 107        54
# 242        81
# 364        74
# 141        71
# 547        66
# 69         74
# 100        52
# 121        53
# 245        65
# 124        50
# 295        59
# 195        59
# 228        81
# 379        86
# 254        46
# ..        ...
# 162        36
# 250        59
# 497        38
# 126        38
# 399        43
# 303        42
# 203        39
# 471        61
# 231        60
# 480        73
# 385        45
# 481        83
# 186        34
# 302        67
# 447        60
# 425        48
# 338        73
# 423        59
# 204        52
# 449        71
# 515        60
# 507        65
# 421        45
# 398        74
# 451        66
# 221        44
# 360        37
# 554        54
# 187        73
# 365        56
#
# [66 rows x 5 columns]

# %% [markdown]
# ### The OLS regression analysis shows that the Audience score has a higher beta and T score than the critics score. This information shows that the audience score along with the budget is the best predictor of revenue.

# %% [markdown]
# # Part 2: Movie Critic Sentiment Analysis with Natural Language Processing

# %% [markdown]
# ## For the second piece of our project we used Natural Language Processing to assess movie critic reviews. We sought out to compare the language that they use in the review against their actual quantative score of the movie.

# %%
"""
This code is referenced from
http://streamhacker.com/2010/05/24/text-classification-sentiment-analysis-stopwords-collocations/
I found the tutorials to be verify informative and gave code examples for 
how to train the Naive Bayes Classifier with a bag of words
"""
# Function to make dictionary of ("word", True) for Naive bayes classifier
def word_feats(words):
    return dict([(word, True) for word in words])

# Function to make dictionary of (("word", 'word'), True) for Naive bayes classifier
def bigram_word_feats(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return dict([(ngram, True) for ngram in itertools.chain(words, bigrams)])

# %% [markdown]
# This function below code trains the Naive Bayes Classifier on the NLTK “movie reviews” corpus. It uses the bag of words approach by splitting the NLTK corpus named "movie reviews" in to two different labels - “pos” and “neg”. The words from the positive and negative reviews are then split in to training and test splits by taking 75% of the total words for training and 25% for test.
#
# The Naive Bayes Classifier treats features independently by determining which feature is the most common occuring within a label. These features then “vote” against one another to determine the label of a feature. The Naive Bayes then returns the probability that a feature belongs to each respective label.

# %%
"""
This code is referenced from
http://streamhacker.com/2010/05/24/text-classification-sentiment-analysis-stopwords-collocations/
"""
# Function returns a trained NB Classifier
def evaluate_classifier(featx):
    
    negids = movie_reviews.fileids('neg')
    posids = movie_reviews.fileids('pos')
 
    negfeats = [(featx(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
    posfeats = [(featx(movie_reviews.words(fileids=[f])), 'pos') for f in posids]
 
    negcutoff = len(negfeats)*3/4
    poscutoff = len(posfeats)*3/4
 
    trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
    testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
 
    classifier = NaiveBayesClassifier.train(trainfeats)
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)
 
    for i, (feats, label) in enumerate(testfeats):
            refsets[label].add(i)
            observed = classifier.classify(feats)
            testsets[observed].add(i)
 
    print 'accuracy:', nltk.classify.util.accuracy(classifier, testfeats)
    print 'pos precision:', nltk.metrics.precision(refsets['pos'], testsets['pos'])
    print 'pos recall:', nltk.metrics.recall(refsets['pos'], testsets['pos'])
    print 'neg precision:', nltk.metrics.precision(refsets['neg'], testsets['neg'])
    print 'neg recall:', nltk.metrics.recall(refsets['neg'], testsets['neg'])
    
    classifier.show_most_informative_features()
    top15_important = classifier.most_informative_features()[:15]
    
    return classifier

# %% [markdown]
# The Naive Bayes Classifier is approximately 73% accurate when trained with individual words from the pos/neg bag of words. The classifier has very good positive recall (98%), which means that it doesn’t predicate many false negatives (predicting a negative word when it is actually positive).  However, the positive precision is somewhat lower (~65%). This means that classifier incorrectly predicts positives often leading to false positives (predicts a positive word when the word is actually negative).
#
# Conversely, negative precision is very high (~96 %), which means that any word that is classified as negative is very likely to be correct (low false positives). The negative recall is very low (~48%), which means that a high number of words are incorrectly classified as negative (high false negatives).
#
# The function also outputs the most important features with their respective classes. These are the most occurring features within the positive and negative classes. Most of the words are adjectives which makes sense as they are descriptive words.

# %%
class_naive = evaluate_classifier(word_feats)
# Out:
# accuracy:
# 0.728
# pos precision: 0.651595744681
# pos recall: 0.98
# neg precision: 0.959677419355
# neg recall: 0.476
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0

# %% [markdown]
# Training the NB Classifier with bigrams improves the accuracy (by roughly 8%), positive precision (by roughly 10%), and the negative recall (roughly 20%). It does slight decrease the positive recall (~4%) and negative precision (~3%) but these are slight losses for big gains. The increase in negative recall checks out as the inclusion of 2 words (such as “not good”) makes it much easier to avoid false negatives (incorrectly labeling as positive when actually negative).
#
# The most important features are returned once again and we see that “Matt Damon” is apparently an important feature in predicting positive movie reviews from critics :)

# %%
class_bigram = evaluate_classifier(bigram_word_feats)
# Out:
# accuracy:
# 0.816
# pos precision: 0.753205128205
# pos recall: 0.94
# neg precision: 0.920212765957
# neg recall: 0.692
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#      (u'matt', u'damon') = True              pos : neg    =     12.3 : 1.0
#         (u'give', u'us') = True              neg : pos    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#   (u'absolutely', u'no') = True              neg : pos    =     10.6 : 1.0

# %%
# Import Movie budgets 
movie_budgetDF = pd.read_csv('movieRTAndBudgetData.csv')

print 'We gathered budget and rotten tomatoes data for', len(movie_budgetDF), 'movies'
movie_budgetDF.head()
# Out:
# We gathered budget and rotten tomatoes data for 1019 movies
#    AudScore                                               Cast  CriticsScore  \
# 0        90  [{"name": "Christian Bale", "characters": ["Br...            88
# 1        52  [{"name": "Johnny Depp", "characters": ["Tonto...            31
# 2        60  [{"name": "Antonio Sabato Jr.", "id": "2706744...            51
# 3        87  [{"name": "Ron Perlman", "characters": ["Stabb...            89
# 4        83  [{"name": "Orlando Bloom", "characters": ["Leg...            64
#
#                                 Name  \
# 0              The Dark Knight Rises
# 1                    The Lone Ranger
# 2                        John Carter
# 3                            Tangled
# 4  The Hobbit: An Unexpected Journey
#
#                                               RTData       RTID  Rank  \
# 0  {"ratings": {"critics_score": 88, "audience_sc...  771041731     3
# 1  {"ratings": {"critics_score": 31, "audience_sc...  771017189     4
# 2  {"ratings": {"critics_score": 51, "audience_sc...  770801433     5
# 3  {"ratings": {"critics_score": 89, "audience_sc...  770678818     6
# 4  {"ratings": {"critics_score": 64, "audience_sc...  770675766     8
#
#                                              Ratings  \
# 0  {"critics_score": 88, "audience_score": 90, "c...
# 1  {"critics_score": 31, "audience_score": 52, "c...
# 2  {"critics_score": 51, "audience_score": 60, "c...
# 3  {"critics_score": 89, "audience_score": 87, "c...
# 4  {"critics_score": 64, "audience_score": 83, "c...
#
#                                              RevLink ReleaseDate     Budget  \
# 0  http://api.rottentomatoes.com/api/public/v1.0/...  2012-07-20  275000000
# 1  http://api.rottentomatoes.com/api/public/v1.0/...  2013-07-02  275000000
# 2  http://api.rottentomatoes.com/api/public/v1.0/...  2012-03-09  275000000
# 3  http://api.rottentomatoes.com/api/public/v1.0/...  2010-11-24  260000000
# 4  http://api.rottentomatoes.com/api/public/v1.0/...  2012-12-14  250000000
#
#     Domestic   Worldwide  Year  Month
# 0  448139099  1079343943  2012      7
# 1   89289910   259989910  2013      7
# 2   73058679   282778100  2012      3
# 3  200821936   586581936  2010     11
# 4  303003568  1014703568  2012     12

# %%
# Import Moview Reviews
movie_reviewDF = pd.read_csv('movieReviewsPat.csv')
movie_review_names = movie_reviewDF.Name.values

print 'We gathered rotten tomatoe critic reviews for' , len(movie_review_names), 'movies'
movie_reviewDF.head()
# Out:
# We gathered rotten tomatoe critic reviews for 875 movies
#                     Name                                       Reviews_JSON
# 0       12 Years a Slave  ["The cumulative emotional effect is devastati...
# 1              127 Hours  ["", "It's an incredible performance by Franco...
# 2                 2 Guns  ["Washington and Wahlberg have a good time rob...
# 3  2016: Obamas America  ["The film is a sleepy dud, a polemic that, li...
# 4         21 Jump Street  ["The late-eighties TV series is rebooted with...

# %%
# Merge both dataframes together
subset_movieDF = movie_budgetDF[['Name', 'CriticsScore', 'AudScore', 'Rank']]
overall_movieDF = subset_movieDF.merge(movie_reviewDF, on='Name')
overall_names = overall_movieDF.Name.values
overall_movieDF.head()
# Out:
#                                 Name  CriticsScore  AudScore  Rank  \
# 0              The Dark Knight Rises            88        90     3
# 1                    The Lone Ranger            31        52     4
# 2                        John Carter            51        60     5
# 3                            Tangled            89        87     6
# 4  The Hobbit: An Unexpected Journey            64        83     8
#
#                                         Reviews_JSON
# 0  ["The story is dense, overlong, and studded wi...
# 1  ["This isn't the complete disaster of Wild Wil...
# 2  ["A mess.", "The most indelible performance in...
# 3  ["I can't help liking a movie with chameleon r...
# 4  ["It frequently seems as though Jackson was le...

# %%
# Function that returns the number of critic moive reviews
def movie_review_len(row):
    review_list = json.loads(row.Reviews_JSON)
    return len(review_list)

# %%
# Call function and remove movies with less than 10 movie reivews
overall_movieDF["Num_Reviews"] = overall_movieDF.apply(movie_review_len, 1)
overall_movieDF = overall_movieDF[overall_movieDF.Num_Reviews > 10]

# %%
print 'We preformed sentiment analysis for', len(overall_movieDF), 'movies'
overall_movieDF.head()
# Out:
# We preformed sentiment analysis for 785 movies
#                                 Name  CriticsScore  AudScore  Rank  \
# 0              The Dark Knight Rises            88        90     3
# 1                    The Lone Ranger            31        52     4
# 2                        John Carter            51        60     5
# 3                            Tangled            89        87     6
# 4  The Hobbit: An Unexpected Journey            64        83     8
#
#                                         Reviews_JSON  Num_Reviews
# 0  ["The story is dense, overlong, and studded wi...           49
# 1  ["This isn't the complete disaster of Wild Wil...           44
# 2  ["A mess.", "The most indelible performance in...           43
# 3  ["I can't help liking a movie with chameleon r...           37
# 4  ["It frequently seems as though Jackson was le...           48

# %%
# Import freshness score information on each critic's review 
budget_review_DF = pd.read_csv('movieRTAndBudgetDataAndReviews.csv')
total_budget_reviewDF = budget_review_DF[['Critic', 'Name', 'Publication', 'Quote', 'Freshness']]
total_budget_reviewDF = total_budget_reviewDF.set_index('Name')

print "We gathered additional critic review information on", len(total_budget_reviewDF), 'movie reviews'
total_budget_reviewDF.head()
# Out:
# We gathered additional critic review information on 26889 movie reviews
#                                 Critic                Publication  \
# Name
# The Dark Knight Rises     Anthony Lane                 New Yorker
# The Dark Knight Rises  Christopher Orr               The Atlantic
# The Dark Knight Rises     Peter Rainer  Christian Science Monitor
# The Dark Knight Rises     Bob Mondello                        NPR
# The Dark Knight Rises      Tom Charity                    CNN.com
#
#                                                                    Quote  \
# Name
# The Dark Knight Rises  The story is dense, overlong, and studded with...
# The Dark Knight Rises  There was an opportunity here for Nolan to sho...
# The Dark Knight Rises  I'm not arguing that Rises should be Singin' i...
# The Dark Knight Rises  The biggest surprise may just be how satisfyin...
# The Dark Knight Rises  Others will see it differently, but for me thi...
#
#                       Freshness
# Name
# The Dark Knight Rises    rotten
# The Dark Knight Rises     fresh
# The Dark Knight Rises    rotten
# The Dark Knight Rises     fresh
# The Dark Knight Rises    rotten

# %%
"""
Function
--------
review_finder

Function returns a movie review dataframe for individual moviews

Parameters
----------
name : string
    The name of a movie

Returns
-------
movie_DF : Dataframe
    Dataframe with 1 column of RT critic reviews for individual movie
"""
def review_finder(name):
    try: 
        movie = str(name)
        temp_reviewDF = movie_reviewDF.set_index('Name')
        reviewSTR = json.loads(temp_reviewDF.loc[movie].Reviews_JSON)
        
        if reviewSTR == 'NA':
            Movie_DF = 0
        else:
            Movie_DF = pd.DataFrame(reviewSTR, columns = [movie])

        return Movie_DF
    
    except Exception, e:
        print 'Failed in movie dataframe builder function'
        print str(e)

# %% [markdown]
# The below function uses the Naive Bayes Classifier to predict the probablility of a word being positive or negative. It then assigns a rating based on the amount of positive, negative, and netural (positive probability = negative probabilty) words in the sentence.
#
# We decided to review key parts of the sentence such as:
# - Verbs, which includes: VB (base form ie. take), VBD (past tense ie. took), VBG (gerund/present participle ie. taking), VBN (past participle ie. taken), VBP (singular present, non-3d ie. take), VBZ (3rd person sing. present ie. takes)
# - Adjectives, which includes: JJ (base form ie. big), JJR (comparative ie. bigger), JJS (superlative ie. biggest)
# - Nouns, which includes: NN (singular or mass ie. door), NNS (plural ie. doors), NNP (proper noun singular ie. John), NNPS (proper noun plural ie. Patriots)
# - Adverb, which includes: RB (base ie. however, usually, etc.), RBR (comparative ie. better), RBS (superlative ie. best)

# %%
"""
Function
--------
review_sentiment

Function returns a sentiment rating for a critic's movie review

Parameters
----------
sentence: string
    The movie review

Returns
-------
review : string
    Returns neg, pos, net based on the sentiment analysis
"""
def review_sentiment(sentence):
    try:
        tokenized = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(tokenized)
        stripped = re.findall(r'\(\u\'(\w*)\',\s\'(VB\w?|JJ\w?|NN\w?|RB\w?)\'', str(tagged))
        tags = re.findall(r'\(\'(\w*)\'', str(stripped))

        probs = map(lambda x: class_naive.prob_classify({x: True}), tags)
        pos_prob = zip(tags, map(lambda x: x.prob("pos"), probs))
        neg_prob = zip(tags, map(lambda y: y.prob("neg"), probs))

        pos_word = []
        neg_word = []
        for x in pos_prob:
            if (x[1] > 0.5) == True: pos_word.append(x)
            elif (x[1] < 0.5) == True: neg_word.append(x) 
        
        if len(pos_word) > len(neg_word): review = 'fresh' 
        elif len(pos_word) < len(neg_word): review = 'rotten'
        else: review = 'net'
        
        return review
        
    except Exception, e:
        print 'Failed in sentiment review function'
        print str(e)

# %% [markdown]
# This function is similiar to the above function, however it uses the Naive Bayes Classifier trained using bigrams. Bigrams are two adjencent words from a sentence/s that are grouped together.

# %%
"""
Function
--------
review_bigram

Function returns a sentiment rating for a critic's movie review

Parameters
----------
sentence: string
    The movie review

Returns
-------
Rating : str
    Either "Positive", Negative"s
"""

def review_bigram(sentence):
    try:
        bigram_finder = BigramCollocationFinder.from_words(nltk.word_tokenize(sentence))
        bigram = bigram_finder.nbest(BigramAssocMeasures.chi_sq, 80)
        bigram_dict = dict([(ngram, True) for ngram in itertools.chain(bigram)])

        prob_bigram = class_bigram.prob_classify(bigram_dict)
        pos_prob = prob_bigram.prob("pos")
        neg_prob = prob_bigram.prob("neg")

        #print "pos:", pos_prob, "neg:", neg_prob, '\n'

        if pos_prob > neg_prob:
            return 'fresh'
        elif neg_prob > pos_prob:
            return 'rotten'
    
    except Exception, e:
        print 'Failed in review_bigram function'
        print str(e)

# %%
"""
Function
--------
assign_reviews

Function that assigns overall score to a movie by reviewing all critic's reviews
for a particular film. Similiar to the Rotten Tomatoe freshness score

Parameters
----------
data: DF
    data is moive's dataframe of critic revies 
classifer: str
    Either 'naive' or 'bigram' 

Returns
-------
sentiment_reviews_score : int
    Percentage of positive reviews over all critic reviews
freshness_score : int
    The amount of times the classifier prediction matches the critics review
fresh_count : int
    The total amount of reviews that are predicted as fresh
"""

def assign_reviews(dataDF, classifier):
    try:
        if len(dataDF) <= 2:
            return 'NA', 'NA', 'NA'
            raise ValueError("There are not enough reviews for this movie")

        sentiment_reviews_score = []
        if classifier == 'naive':
            for index, row in dataDF.iterrows():
                    sentiment_reviews_score.append(review_sentiment(row[0]))
        elif classifier == 'bigram':
            for index, row in dataDF.iterrows():
                    sentiment_reviews_score.append(review_bigram(row[0]))

        net_count = list(sentiment_reviews_score).count('net')
        fresh_count = list(sentiment_reviews_score).count('fresh')
        rotten_count = list(sentiment_reviews_score).count('rotten')

        all_reviews = len(dataDF)-net_count
        freshness_score = np.round((fresh_count*1.0/all_reviews*1.0)*100)
        
        return sentiment_reviews_score, freshness_score, fresh_count
    
    except Exception, e:
        print 'Failed in assign_reviews function'
        print str(e)

# %%
# Function that compares the Freshness score to the sentiment score for each movie
def compare_results(row):
    try:
        if row.Freshness == row.Sentiment: compare = True
        else: compare = False
        return compare
    
    except Exception, e:
        print 'Failed in compare_results function'
        print str(e)

# %%
"""
Function
--------
assign_reviews

Given a list of movies and a classifier, function classifies all movies and returns a sentiment percentage 
and the classifier score

Parameters
----------
movie_names: list
    list of movies to review
classifer: str
    Either 'naive' or 'bigram' 

Returns
-------
all_movies_fresh_score : list of ints
    Sentiment percent score, the ratio of "fresh" reviews to all reviews for each movie
classifier_score : list of ints
    Classifier score, how well the classifier predicted the critic review for each movie
"""
def rate_movies(movie_names, classifier):
    try:
        classifier_score = []
        all_movies_fresh_score = []
    
        for x in movie_names:
            temp_movieDF = review_finder(x)
            print '###########', x, '###########'
            
            sentiment_reviews, movies_fresh_score, fresh_reviews = assign_reviews(temp_movieDF, classifier)
            temp_movieDF['Sentiment'] = sentiment_reviews
            temp_movieDF['Freshness'] = total_budget_reviewDF.loc[x].Freshness.values
            temp_movieDF['Compare'] = temp_movieDF.apply(compare_results,1)
            
            classifier_score.append(np.round((temp_movieDF.Compare.sum()*1.0)/(len(sentiment_reviews)*1.0)*100.0))
            all_movies_fresh_score.append(movies_fresh_score)
            print "Fresh Reviews:", fresh_reviews, "Total Reviews:", len(temp_movieDF), "Score:", movies_fresh_score, '\n'

        return all_movies_fresh_score, classifier_score
    
    except Exception, e:
        print 'Failed in rate_movie function'
        print str(e)

# %%
naive_movie_scores, classifier_scores= rate_movies(overall_movieDF.Name.values, 'naive')
# Out:
# ########### The Dark Knight Rises ###########
# Fresh Reviews:
#  34 Total Reviews: 49 Score: 76.0
#
# ########### The Lone Ranger ###########
# Fresh Reviews:
#  20 Total Reviews: 44 Score:
#  15 Total Reviews: 19 Score: 88.0
#
# ########### My Dog Tulip ###########
# Fresh Reviews:
#  14 Total Reviews: 17 Score: 93.0
#
# ########### Like Crazy ###########
# Fresh Reviews:
#  35 Total Reviews: 42 Score: 92.0
#
# ########### The Canyons ###########
# Fresh Reviews:
#  17 Total Reviews: 28 Score: 71.0
#
# ########### The Grace Card ###########
# Fresh Reviews:
#  8 Total Reviews: 14 Score: 67.0
#
# ########### Weekend ###########
# Fresh Reviews:
#  21 Total Reviews: 28 Score: 88.0
#
# ########### Another Earth ###########
# Fresh Reviews:
#  23 Total Reviews: 36 Score: 74.0
#
# ########### Your Sister's Sister ###########
# Fresh Reviews:
#  30 Total Reviews: 41 Score: 77.0
#
# ########### Cheap Thrills ###########
# Fresh Reviews:
#  14 Total Reviews: 18 Score: 78.0
#
# ########### Tiny Furniture ###########
# Fresh Reviews:
#  25 Total Reviews: 29 Score: 93.0
#
# ########### This Is Martin Bonner ###########
# Fresh Reviews:
#  8 Total Reviews: 11 Score: 80.0
#
# ########### The Exploding Girl ###########
# Fresh Reviews:
#  10 Total Reviews: 14 Score: 77.0
#
# ########### Breaking Upwards ###########
# Fresh Reviews:
#  7 Total Reviews: 11 Score: 78.0

# %%
overall_movieDF['Classifier_Score'] = classifier_scores
overall_movieDF['Sentiment_Score'] = naive_movie_scores
print 'Completed sentiment analysis for', len(overall_movieDF), 'movies'
overall_movieDF.head()
# Out:
# Completed sentiment analysis for 785 movies
#                                 Name  CriticsScore  AudScore  Rank  \
# 0              The Dark Knight Rises            88        90     3
# 1                    The Lone Ranger            31        52     4
# 2                        John Carter            51        60     5
# 3                            Tangled            89        87     6
# 4  The Hobbit: An Unexpected Journey            64        83     8
#
#                                         Reviews_JSON  Num_Reviews  \
# 0  ["The story is dense, overlong, and studded wi...           49
# 1  ["This isn't the complete disaster of Wild Wil...           44
# 2  ["A mess.", "The most indelible performance in...           43
# 3  ["I can't help liking a movie with chameleon r...           37
# 4  ["It frequently seems as though Jackson was le...           48
#
#    Classifier_Score  Sentiment_Score
# 0                57               76
# 1                55               49
# 2                63               67
# 3                73               73
# 4                44               80

# %%
# Drop NANs in the overall_movieDF
overall_movieDF = overall_movieDF.dropna(axis=0)

# %% [markdown]
# ## The Sentiment_Score column in the above dataframe shows the results of the sentiment analysis of naive classifer using single words for training. The classifier rating is the percentage of reviews that the classifier correctly predicted ie. the Critic's  "Freshness" score against the predicted freshness score.

# %%
plt.figure(figsize=(12, 7))
plt.scatter(overall_movieDF.AudScore, overall_movieDF.Sentiment_Score)
plt.xlabel('Rotten Tomatoes Audience Score')
plt.ylabel('Sentiment Analysis Score')
plt.title('Comparsion of RT Audience Score and Sentiment Analysis,' + ' R=' + 
          str(round(np.corrcoef(overall_movieDF.AudScore, overall_movieDF.Sentiment_Score)[0][1],2)))

m, b = np.polyfit(overall_movieDF.AudScore, overall_movieDF.Sentiment_Score, 1)
x = np.linspace(overall_movieDF.AudScore.min(), overall_movieDF.AudScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# %% [markdown]
# ### The above plot shows that the movie review sentiment analysis score has a positive correlation with the audience score. Which agrees with our previous regression analysis that critic scores have a positive correlation with audience scores.

# %%
plt.figure(figsize=(12, 7))
plt.scatter(overall_movieDF.CriticsScore, overall_movieDF.Sentiment_Score)
plt.xlabel('Rotten Tomatoes Critic Score')
plt.ylabel('Sentiment Analysis Score')
plt.title('Comparsion of RT Critic Score and Sentiment Analysis'+ ' R=' +
          str(round(np.corrcoef(overall_movieDF.CriticsScore, overall_movieDF.Sentiment_Score)[0][1],2)))

m, b = np.polyfit(overall_movieDF.CriticsScore, overall_movieDF.Sentiment_Score, 1)
x = np.linspace(overall_movieDF.CriticsScore.min(), overall_movieDF.CriticsScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# %% [markdown]
# ### The above plot shows that there is a strong correlation between the movie review sentiment score and the critic's "freshness" score. This seems intutive but there are a good amount of reviews that use positive language to describe the movie but end up rating the film as "rotten".

# %%
bigram_movie_scores, bigram_classifier_scores = rate_movies(overall_movieDF.Name.values, 'bigram')
# Out:
# ########### The Dark Knight Rises ###########
# Fresh Reviews:
#  21 Total Reviews: 49 Score: 43.0
#
# ########### The Lone Ranger ###########
# Fresh Reviews:
#  14 Total Reviews: 44 Score: 32.0
#
# ########### John Carter ###########
# Fresh Reviews:
#  19 Total Reviews: 43 Score: 44.0
#
# ########### Tangled ###########
# Fresh Reviews: 11 Total Reviews: 37 Score: 30.0
#
# ########### The Hobbit: An Unexpected Journey ###########
# Fresh Reviews:
#  19 Total Reviews: 48 Score: 40.0
#
# ########### The Hobbit: The Desolation of Smaug ###########
# Fresh Reviews:
#  15 Total Reviews: 44 Score: 34.0
#
# ########### Pirates of the Caribbean: On Stranger Tides ###########
# Fresh Reviews:
#  16 Total Reviews: 43 Score: 37.0
#
# ########### The Avengers ###########
# Fresh Reviews:
#  21 Total Reviews: 49 Score: 43.0
#
# ########### Man of Steel ###########
# Fresh Reviews:
#  17 Total Reviews: 50 Score: 34.0
#
# ########### The Amazing Spider-Man ###########
# Fresh Reviews:
#  19 Total Reviews: 46 Score: 41.0
#
# ########### Men in Black 3 ###########
# Fresh Reviews:
#  15 Total Reviews: 41 Score: 37.0
#
# ########### Transformers: Age of Extinction ###########
# Fresh Reviews:
#  19 Total Reviews: 43 Score: 44.0
#
# ########### Robin Hood ###########
# Fresh Reviews:
#  12 Total Reviews: 42 Score: 29.0
#
# ########### Battleship ###########
# Fresh Reviews:
#  16 Total Reviews: 41 Score: 39.0
#
# ########### Toy Story 3 ###########
# Fresh Reviews:
#  27 Total Reviews: 49 Score: 55.0
#
# ########### Iron Man 3 ###########
# Fresh Reviews:
#  19 Total Reviews: 49 Score: 39.0
#
# ########### Alice in Wonderland ###########
# Fresh Reviews:
#  17 Total Reviews: 46 Score: 37.0
#
# ########### Skyfall ###########
# Fresh Reviews:
#  27 Total Reviews: 50 Score: 54.0
#
# ########### Monsters University ###########
# Fresh Reviews:
#  16 Total Reviews: 43 Score: 37.0
#
# ########### Oz the Great and Powerful ###########
# Fresh Reviews:
#  15 Total Reviews: 48 Score: 31.0
#
# ########### X-Men: Days of Future Past ###########
# Fresh Reviews:
#  20 Total Reviews: 47 Score: 43.0
#
# ########### The Amazing Spider-Man 2 ###########
# Fresh Reviews:
#  20 Total Reviews: 50 Score: 40.0
#
# ########### Cars 2 ###########
# Fresh Reviews:
#  14 Total Reviews: 44 Score: 32.0
#
# ########### Safety Not Guaranteed ###########
# Fresh Reviews:
#  13 Total Reviews: 34 Score: 38.0
#
# ########### Drinking Buddies ###########
# Fresh Reviews: 10 Total Reviews: 26 Score: 38.0
#
# ########### Monsters ###########
# Fresh Reviews:
#  9 Total Reviews: 29 Score: 31.0
#
# ########### Deceptive Practice: The Mysteries and Mentors of Ricky Jay ###########
# Fresh Reviews: 11 Total Reviews: 22 Score: 50.0
#
# ###########
#  The Other Dream Team ###########
# Fresh Reviews: 7 Total Reviews: 19 Score: 37.0
#
# ########### My Dog Tulip ###########
# Fresh Reviews:
#  12 Total Reviews: 17 Score: 71.0
#
# ########### Like Crazy ###########
# Fresh Reviews:
#  18 Total Reviews: 42 Score: 43.0
#
# ########### The Canyons ###########
# Fresh Reviews: 5 Total Reviews: 28 Score: 18.0
#
# ########### The Grace Card ###########
# Fresh Reviews:
#  6 Total Reviews: 14 Score: 43.0
#
# ########### Weekend ###########
# Fresh Reviews: 12 Total Reviews: 28 Score: 43.0
#
# ########### Another Earth ###########
# Fresh Reviews:
#  15 Total Reviews: 36 Score: 42.0
#
# ########### Your Sister's Sister ###########
# Fresh Reviews:
#  13 Total Reviews: 41 Score: 32.0
#
# ########### Cheap Thrills ###########
# Fresh Reviews: 7 Total Reviews: 18 Score: 39.0
#
# ########### Tiny Furniture ###########
# Fresh Reviews:
#  15 Total Reviews: 29 Score: 52.0
#
# ########### This Is Martin Bonner ###########
# Fresh Reviews: 4 Total Reviews: 11 Score: 36.0
#
# ########### The Exploding Girl ###########
# Fresh Reviews: 9 Total Reviews: 14 Score: 64.0
#
# ########### Breaking Upwards ###########
# Fresh Reviews:
#  4 Total Reviews: 11 Score: 36.0

# %%
overall_movieDF['Sentiment_Bi_Score'] = bigram_movie_scores
overall_movieDF['Classifier__Bi_Rating'] = bigram_classifier_scores
overall_movieDF.head()
# Out:
#                                 Name  CriticsScore  AudScore  Rank  \
# 0              The Dark Knight Rises            88        90     3
# 1                    The Lone Ranger            31        52     4
# 2                        John Carter            51        60     5
# 3                            Tangled            89        87     6
# 4  The Hobbit: An Unexpected Journey            64        83     8
#
#                                         Reviews_JSON  Num_Reviews  \
# 0  ["The story is dense, overlong, and studded wi...           49
# 1  ["This isn't the complete disaster of Wild Wil...           44
# 2  ["A mess.", "The most indelible performance in...           43
# 3  ["I can't help liking a movie with chameleon r...           37
# 4  ["It frequently seems as though Jackson was le...           48
#
#    Classifier_Score  Sentiment_Score  Sentiment_Bi_Score  \
# 0                57               76                  43
# 1                55               49                  32
# 2                63               67                  44
# 3                73               73                  30
# 4                44               80                  40
#
#    Classifier__Bi_Rating  Combined_Predictor
# 0                     51                64.3
# 1                     66                40.6
# 2                     51                59.2
# 3                     32                59.2
# 4                     60                68.6

# %%
plt.figure(figsize=(12, 7))
plt.scatter(overall_movieDF.AudScore, overall_movieDF.Sentiment_Bi_Score)
plt.xlabel('Rotten Tomatoes Audience Score')
plt.ylabel('Sentiment Bigram Analysis Score')
plt.title('Comparsion of RT Audience Score and Bigram Sentiment Analysis' + ' R=' +
          str(round(np.corrcoef(overall_movieDF.AudScore, overall_movieDF.Sentiment_Bi_Score)[0][1],2)))

m, b = np.polyfit(overall_movieDF.AudScore, overall_movieDF.Sentiment_Bi_Score, 1)
x = np.linspace(overall_movieDF.AudScore.min(), overall_movieDF.AudScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# %% [markdown]
# ### The correlation between the bigram Naive Bayes and the audience score is not as high as the original bayes classifier. This may be because the bigrams can be sparse when dealing with a short one line review sentence.

# %%
plt.figure(figsize=(12, 7))
plt.scatter(overall_movieDF.CriticsScore, overall_movieDF.Sentiment_Bi_Score)
plt.xlabel('Rotten Tomatoes Critic Score')
plt.ylabel('Sentiment Bigram Analysis Score')
plt.title('Comparsion of RT Critic Score and Bigram Sentiment Analysis' + ' R=' +
          str(round(np.corrcoef(overall_movieDF.CriticsScore, overall_movieDF.Sentiment_Bi_Score)[0][1],2)))

m, b = np.polyfit(overall_movieDF.CriticsScore, overall_movieDF.Sentiment_Bi_Score, 1)
x = np.linspace(overall_movieDF.CriticsScore.min(), overall_movieDF.CriticsScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# %% [markdown]
# ### Once again, the bigram verison of the naive bayes classifier does not do as well the original classifier.

# %% [markdown]
# Overall, the Naive Bayes Classifier trained with individual words out performs the Bigram approach. Both classifiers show that the verbiage in a movie review don't always match with the critic's overall "freshness" score (Rotten or Fresh). Also it is estimated that humans are only 80% accurate in predicting sentiment. Many times a review would mention positive attributes of the film, only to end up saying that them film was not good.
#
# Here is an example of a "rotten" film review from The Dark Knight:
# "This is an impressive film in many ways, and Nolan directs with real confidence, yet the overall result feels cumbersome."
# Words like impressive and confidence would most likely return as positive words, while cubersome would return as negative. When weighting all words in the sentence it is difficult to predict this behavior.

# %%
# Combine regression results with the budget data frame
dataMain_sent_movieDF = dataMain.merge(overall_movieDF)

# %%
plt.figure(figsize=(12, 7))
plt.hist(overall_movieDF.Sentiment_Score)
plt.xlabel('Sentiment Score using Individual Words')
plt.ylabel('Frequency')
plt.title('Histogram of Movie Sentiment Analysis')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### The above plot shows that sentiment analysis scores are relative normally distrubted slightly

# %%
plt.figure(figsize=(12, 7))
plt.hist(overall_movieDF.Sentiment_Bi_Score)
plt.xlabel('Sentiment Score using Bigrams')
plt.ylabel('Frequency')
plt.title('Histogram of Bigram Sentiment Analysis')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# After further analysis, we noticed that the Naive Bayes with individual words tends to do a better job of predicting positive critic sentiment while it struggles to predict negative reviews. This makes coincides with the classifier’s internal verification, the high positive recall score means that all of the true positives in the data are found but the lower positive precision leads to a high amount of false positives (classifying words as positive when they are actually negative).
#
# The Bigram Naive Bayes approach does a better job of predicting negative reviews, as indicated by it's higher negative recall score. It is finding more the negative verbiage in the reviews (less false positives or classifying a word as positive when it is actually negative).
#
# So we decided to use an combination of both approaches to predict the critic's freshness score by coming up with a weighted predictor. First, we plugged the results of both sentiment in to a regression model to determine the coefficients to weight them by.

# %%
# Run regression model for both sentiment scores
y, X = dataMain_sent_movieDF["CriticsScore"],dataMain_sent_movieDF[["Sentiment_Score","Sentiment_Bi_Score"]]
model = sm.OLS(y,X)
res = model.fit()
print res.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           CriticsScore   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     3182.
# Date:                Wed, 10 Dec 2014   Prob (F-statistic):               0.00
# Time:                        09:31:30   Log-Likelihood:                -3416.0
# No. Observations:                 775   AIC:                             6836.
# Df Residuals:                     773   BIC:                             6845.
# Df Model:                           2
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Sentiment_Score        0.5941      0.041     14.460      0.000         0.513     0.675
# Sentiment_Bi_Score     0.3776      0.074      5.083      0.000         0.232     0.523
# ==============================================================================
# Omnibus:                      165.398   Durbin-Watson:                   1.782
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.746
# Skew:                          -0.188   Prob(JB):                     1.05e-08
# Kurtosis:                       2.002   Cond. No.                         9.59
# ==============================================================================

# %%
# Calculate the weighted combined sentiment predictor
overall_movieDF["Combined_Predictor"] = (overall_movieDF.Sentiment_Score*.7 + overall_movieDF.Sentiment_Bi_Score*.3)

# %%
overall_movieDF[["Name", "CriticsScore", "AudScore", "Num_Reviews", 
                 "Sentiment_Score", "Sentiment_Bi_Score", "Combined_Predictor"]].head()
# Out:
#                                 Name  CriticsScore  AudScore  Num_Reviews  \
# 0              The Dark Knight Rises            88        90           49
# 1                    The Lone Ranger            31        52           44
# 2                        John Carter            51        60           43
# 3                            Tangled            89        87           37
# 4  The Hobbit: An Unexpected Journey            64        83           48
#
#    Sentiment_Score  Sentiment_Bi_Score  Combined_Predictor
# 0               76                  43                66.1
# 1               49                  32                43.9
# 2               67                  44                60.1
# 3               73                  30                60.1
# 4               80                  40                68.0

# %%
plt.figure(figsize=(12, 7))
plt.scatter(overall_movieDF.CriticsScore, overall_movieDF.Combined_Predictor)
plt.xlabel('Rotten Tomatoes Audience Score')
plt.ylabel('Sentiment Bigram Analysis Score')
plt.title('Comparsion of RT Audience Score and Bigram Sentiment Analysis' + ' R=' +
          str(round(np.corrcoef(overall_movieDF.CriticsScore, overall_movieDF.Combined_Predictor)[0][1],2)))

m, b = np.polyfit(overall_movieDF.CriticsScore, overall_movieDF.Combined_Predictor, 1)
x = np.linspace(overall_movieDF.CriticsScore.min(), overall_movieDF.CriticsScore.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()

# %% [markdown]
# ### Looking at the above plot, we can see that using a combination of both Bigram's and the Naive Bayes does a slightly better job of predicting the movie critic's score.

# %%
# Model 3 -- Final Model w/ Sentiment Analysis: Budget and Critics Score
dataMainActorsSent = dataMainActors.merge(overall_movieDF)

#spilt the data into test and train, ignore indie movies
dataTrainSent = dataMainActorsSent[(dataMainActorsSent["Year"] < 2014) & (dataMainActorsSent["Budget"] > 15)]
dataTestSent = dataMainActorsSent[(dataMainActorsSent["Year"] == 2014) & (dataMainActorsSent["Budget"] > 15) 
                               & (dataMainActorsSent["Month"] < 10)]

# train the model
y,X = dataTrainSent["logWorldwide"], dataTrainSent[["logBudget", "Combined_Predictor"]]
model = sm.OLS(y, X)
res = model.fit()
print res.summary()
# print res.params

# predict the revenues for the test dataset
Xbar = dataTestSent[["logBudget", "Combined_Predictor"]]
dataTestSent["predLogWorldwide"] = res.predict(Xbar)
dataTestSent["predWorldwide"] = dataTestSent["predLogWorldwide"].apply(lambda x: exp(x))

# plot the results
dataTestSent.plot("predWorldwide","Worldwide",kind="scatter",alpha=0.5,
                  title="Revenue v/s Critics Score, R=" + str(np.round(res.rsquared, 2)), figsize=(9,9))
m, b = np.polyfit(dataTestSent.predWorldwide, dataTestSent.Worldwide, 1)
x = np.linspace(dataTestSent.predWorldwide.min(), dataTestSent.predWorldwide.max(), 1000)
plt.plot(x, m*x +b, 'r-')
plt.show()
plt.xlim((-1,1000))
plt.ylim((-1,1000))

# show the results
dataTestSent = dataTestSent.sort("Worldwide",ascending=False)
dataTestSent[["Name","Worldwide","predWorldwide","Budget","CriticsScore", "Combined_Predictor"]]
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           logWorldwide   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     4861.
# Date:                Wed, 10 Dec 2014   Prob (F-statistic):          6.97e-306
# Time:                        11:35:03   Log-Likelihood:                -646.40
# No. Observations:                 453   AIC:                             1297.
# Df Residuals:                     451   BIC:                             1305.
# Df Model:                           2
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# logBudget              1.1697      0.043     27.068      0.000         1.085     1.255
# Combined_Predictor     0.0004      0.003      0.154      0.878        -0.005     0.006
# ==============================================================================
# Omnibus:                      203.486   Durbin-Watson:                   1.292
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1172.537
# Skew:                          -1.877   Prob(JB):                    2.44e-255
# Kurtosis:                       9.930   Cond. No.                         54.3
# ==============================================================================
#                                     Name    Worldwide  predWorldwide  Budget  \
# 11       Transformers: Age of Extinction  1081.139076     532.691811     210
# 37               Guardians of the Galaxy   767.805224     419.082045     170
# 33                            Maleficent   751.286891     447.680960     180
# 20            X-Men: Days of Future Past   744.321534     507.638904     200
# 39   Captain America: The Winter Soldier   713.846958     417.463021     170
# 21              The Amazing Spider-Man 2   708.996336     505.227996     200
# 40        Dawn of the Planet of the Apes   703.490841     418.690672     170
# 66            How to Train Your Dragon 2   615.934091     349.420616     145
# 51                              Godzilla   508.172193     389.854474     160
# 79                                 Rio 2   493.738435     305.965261     130
# 87          Teenage Mutant Ninja Turtles   464.177931     287.986066     125
# 198                       The Lego Movie   457.784718     123.908540      60
# 275                                 Lucy   450.573960      76.899838      40
# 35                      Edge of Tomorrow   364.406256     442.084298     178
# 81                                  Noah   356.200044     306.919642     130
# 103               300: Rise of an Empire   330.780051     250.305275     110
# 229                       22 Jump Street   330.634675      99.113694      50
# 340                      The Maze Runner   325.029385      63.759345      34
# 135                            Divergent   286.347895     185.243516      85
# 494                            Neighbors   269.970483      30.302499      18
# 67                 Mr. Peabody & Sherman   269.806430     347.467277     145
# 96                               RoboCop   242.981799     277.789305     120
# 117                             Hercules   242.288614     223.898954     100
# 232                             Non-Stop   212.742160      99.533502      50
# 120                    The Expendables 3   195.322544     222.587882     100
# 278                      The Other Woman   195.111193      75.971452      40
# 185                       Need for Speed   187.268507     136.782845      66
# 217                        The Equalizer   186.915469     111.267390      55
# 354             The Grand Budapest Hotel   158.076019      57.392412      31
# 240                       Into the Storm   156.567524      99.599950      50
# ..                                   ...          ...            ...     ...
# 509                        Lets Be Cops   121.236907      28.018008      17
# 156                              Pompeii   108.469033     172.738797      80
# 236              Planes: Fire and Rescue    96.657732      99.414008      50
# 458                                Tammy    92.025432      33.974795      20
# 122                        Transcendence    90.022309     223.879032     100
# 374                 Deliver Us from Evil    87.937815      54.692388      30
# 286    A Million Ways to Die in The West    86.587088      76.391739      40
# 193                      I, Frankenstein    71.519465     134.517280      65
# 435                 Think Like a Man Too    70.027933      41.834588      24
# 219                  Muppets Most Wanted    68.493504     111.490382      55
# 443                           Son of God    67.513026      38.078177      22
# 360                          The Nut Job    66.251538      54.670492      30
# 444             The Hundred-Foot Journey    66.082798      38.169771      22
# 177               The Legend of Hercules    61.402445     146.040616      70
# 285                          Jersey Boys    59.447013      77.026533      40
# 416                            The Giver    54.972596      44.458417      25
# 395                       Brick Mansions    50.236829      49.911686      28
# 316                       Dolphin Tale 2    44.658250      67.771846      36
# 393          A Walk Among the Tombstones    42.517685      50.733349      28
# 194         Sin City: A Dame to Kill For    39.499349     135.822283      65
# 418                   Million Dollar Arm    36.947959      44.381342      25
# 475                         Endless Love    34.589731      33.937026      20
# 467            This is Where I Leave You    34.119811      33.997476      20
# 391                       3 Days to Kill    33.622417      50.344354      28
# 373                            Get on Up    32.042803      55.083111      30
# 420                            Draft Day    28.842237      44.326088      25
# 210                        Winter's Tale    22.468620     123.435340      60
# 337                             Sabotage    18.376443      65.458419      35
# 501                            Labor Day    13.371528      30.159926      18
# 178      Legends of Oz: Dorothys Return     8.462347     148.424976      70
#
#      CriticsScore  Combined_Predictor
# 11             18                52.4
# 37             90                68.8
# 33             49                66.9
# 20             92                72.4
# 39             89                60.1
# 21             53                61.7
# 40             91                66.7
# 66             92                78.4
# 51             73                65.7
# 79             48                67.0
# 87             22                34.0
# 198            96                68.1
# 275            66                61.9
# 35             90                68.0
# 81             77                74.0
# 103            42                54.9
# 229            84                45.6
# 340            63                68.0
# 135            41                56.2
# 494            73                68.1
# 67             79                65.8
# 96             48                60.3
# 117            58                54.9
# 232            60                55.1
# 120            33                41.7
# 278            24                34.6
# 185            22                39.7
# 217            61                55.0
# 354            92                74.4
# 240            21                56.6
# ..            ...                 ...
# 509            18                42.2
# 156            29                58.5
# 236            44                52.4
# 458            24                48.2
# 122            19                54.7
# 374            28                52.3
# 286            33                47.0
# 193             3                42.3
# 435            23                36.6
# 219            79                59.5
# 443            21                53.9
# 360            10                51.4
# 444            67                59.3
# 177             3                32.2
# 285            53                65.6
# 416            36                66.0
# 395            26                28.1
# 316            69                54.9
# 393            66                64.8
# 194            44                64.0
# 418            61                62.1
# 475            15                45.7
# 467            42                49.7
# 391            29                47.5
# 373            80                68.3
# 420            60                59.3
# 210            13                59.5
# 337            19                50.9
# 501            34                57.5
# 178            16                68.6
#
# [65 rows x 6 columns]

# %% [markdown]
# # Conclusions:

# %% [markdown]
# Adding the sentiment analysis to our regression model does slightly improve the R-squared model. However, it does not add signficant value as it's T score is very low. This is an expected results as our previous regession analysis showed us that audience scores rather than critic scores are the best predictor for how well a film will perform in the box office. However, our sentiment analysis tool could be used for further analysis on audiences who are pre-screening movies. Also, we could improve our sentiment analysis by reviewing the entire fil critic score rather than the short one-line sentence. Using the short version provided by Rotten Tomatoes leads ot spares data when preforming bigram analysis.
